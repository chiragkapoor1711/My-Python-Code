# %%
import re
class calc:
    def add(self, a,b):
        return a + b
    def sub(self, a,b):
        return a - b
    def mul(self, a,b):
        return a * b
    def div(self, a,b):
        if b!=0:
            return a /b
        else:
            print("error , divisble by 0")
    def modu(self, a,b):
        return a % b
class loginsystem:
    def validate_username(self,username):
        pattern= r"^[a-zA-Z0-9]{4,12}$"
        return re.match(pattern,username)
    def validate_password(self,password):
        pattern = r"^(?=.*[a-z])(?=.*[A-Z])(?=.*\d).{8,}$"
        return re.match(pattern,password)
log = loginsystem()
username = input("enter username")
password = input("enter password")

if not log.validate_username(username):
    print("Invalid Username! (4-12 chars, only letters & numbers)")
elif not log.validate_password(password):
    print("Invalid Password! (Min 8 chars, 1 uppercase, 1 lowercase, 1 digit)")
else:
    print("log in successfully ")
    
    cl = calc()
    a = float(input("enter 1st no."))
    b = float(input("enter 2nd no."))

    print("Choose operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Mod")

    choice = input("enter choice 1/2/3/4/5")

    if choice == '1':
        print("result ",cl.add(a,b))
    elif choice == '2':
        print("result",cl.sub(a,b))
    elif choice == '3':
        print("result",cl.mul(a,b))
    elif choice == '4':
        print("result",cl.div(a,b))
    elif choice == '5':
        print("result",cl.modu(a,b))
    else:
        print("invalid choice")
# Out:
# enter username chirag
# enter password Chirag123
# log in successfully
# enter 1st no. 1
# enter 2nd no. 2
# Choose operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Mod
# enter choice 1/2/3/4/5 1
# result  3.0
