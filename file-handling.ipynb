# %%
file = open('cgc.text','w')
file.write('hello cgc')
# Out:
# 9

# %%
file.close()

# %%
file=open('cgc.text','w')
file.write(' i am cgc')
file.close()

# %%
file = open('new_cgc.text','w')
file.write('i am cgc 2 file')
file.close()

# %%
file = open('new_cgc.text','r')
r=file.read()
file.close()

# %%
print(r)
# Out:
# i am cgc 2 file

# %%
file = open('cgc.text','a')
file.write('\n this is line 2')
# Out:
# 16

# %%
file.close()

# %%
with open ('cgc.text','a') as f:
    a = int(input('number of line'))
    for i in range(a):
        data = input()
        f.write(data + '\n')
# Out:
# number of line 3
#  hi
#  my name
#  is chirag

# %%
with open ('cgc.text','r') as f:
    new_content = f.read()
    print(new_content)
# Out:
#  i am cgc
#  this is line 2hi/
# my name /
# is chirag/
# hi
# my name
# is chirag

# %%
with open ('cgc.text','r') as f:
    new_content = f.read(20)
    print(new_content)
# Out:
#  i am cgc
#  this is l
