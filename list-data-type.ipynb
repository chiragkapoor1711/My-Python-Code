# %%
list=[12,2,34,]

# %%
type(list)
# Out:
# list

# %%
print(list)
# Out:
# [12, 2, 34]

# %%
print(list[2])
# Out:
# 34

# %%
list[1]='chirag'

# %%
print(list)
# Out:
# [12, 'chirag', 34]

# %%
list.index('chirag')
# Out:
# 1

# %%
list2=['hello',0,'my','name','is',0,'chirag']

# %%
list2.index(0,2)
# Out:
# 5

# %%
list2.count(0)
# Out:
# 2

# %%
list3=[21,3,4,2,3,5]

# %%
list3.sort()

# %%
print(list3)
# Out:
# [2, 3, 3, 4, 5, 21]

# %%
list3.sort(reverse=True)

# %%
print(list3)
# Out:
# [21, 5, 4, 3, 3, 2]

# %%
list2.append("chirag")

# %%
print(list2)
# Out:
# ['hello', 0, 'my', 'name', 'is', 0, 'chirag', 'chirag']

# %%
list2.remove(0)

# %%
print(list2)
# Out:
# ['hello', 'my', 'name', 'is', 0, 'chirag', 'chirag']

# %%
list2.pop(4)
# Out:
# 0

# %%
l1=[1,2,3]

# %%
l2=[3,4,5]

# %%
l1.extend(l2)

# %%
print(l1)
# Out:
# [1, 2, 3, 3, 4, 5]

# %%
l1.insert(3,'chirag')

# %%
print(l1)
# Out:
# [1, 2, 3, 'chirag', 3, 4, 5]

# %%
list5=[1,2,3,4,[3,4,5,7],4,6]

# %%
print(list5[4])
# Out:
# [3, 4, 5, 7]

# %%
print(list5[4][1:3])
# Out:
# [4, 5]

# %%
list5.append('chirag')

# %%
print(list5)
# Out:
# [1, 2, 3, 4, [3, 4, 5, 7], 4, 6, 'chirag']

# %%
list5[4].append('chirag')

# %%
print(list5)
# Out:
# [1, 2, 3, 4, [3, 4, 5, 7, 'chirag'], 4, 6, 'chirag']
