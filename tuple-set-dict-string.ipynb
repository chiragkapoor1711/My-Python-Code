# %% [markdown]
# #tuple

# %%
tup = (1,2,3,4)

# %%
print(tup)
# Out:
# (1, 2, 3, 4)

# %%
print(type(tup))
# Out:
# <class 'tuple'>

# %% [markdown]
# dictionary

# %%
student ={'name':'chirag','age':21}

# %%
print(student)
# Out:
# {'name': 'chirag', 'age': 21}

# %%
student['address']=2984

# %%
print(student)
# Out:
# {'name': 'chirag', 'age': 21, 'address': 2984}

# %%
del student['age']

# %%
print(student)
# Out:
# {'name': 'chirag', 'address': 2984}

# %%
print(student.get('age','value not found'))
# Out:
# value not found

# %%
student['age']=21

# %%
print(student)
# Out:
# {'name': 'chirag', 'address': 2984, 'age': 21}

# %%
student['age']=23

# %%
print(student)
# Out:
# {'name': 'chirag', 'address': 2984, 'age': 23}

# %%
students={ 'student1':{'name':'chirag','age':21},
           'student2':{'name':'tanishq','age':21}
         }

# %%
print(students)
# Out:
# {'student1': {'name': 'chirag', 'age': 21}, 'student2': {'name': 'tanishq', 'age': 21}}

# %%
print(students['student1'])
# Out:
# {'name': 'chirag', 'age': 21}

# %%
print(students.keys())
# Out:
# dict_keys(['student1', 'student2'])

# %%
print(students.values())
# Out:
# dict_values([{'name': 'chirag', 'age': 21}, {'name': 'tanishq', 'age': 21}])

# %%
print(students.items())
# Out:
# dict_items([('student1', {'name': 'chirag', 'age': 21}), ('student2', {'name': 'tanishq', 'age': 21})])

# %% [markdown]
# #set

# %%
set1={1,2,2,3,4,5,4}

# %%
print(set1)
# Out:
# {1, 2, 3, 4, 5}

# %%
set1.pop()
# Out:
# 1

# %%
set1.update('chirag')

# %%
set1
# Out:
# {2, 3, 4, 5, 'a', 'c', 'g', 'h', 'i', 'r'}

# %%
set1.update({'king'})

# %%
set1
# Out:
# {2, 3, 4, 5, 'a', 'c', 'g', 'h', 'i', 'king', 'r'}

# %% [markdown]
# #string methods

# %%
name = "chirag"

# %%
name.upper()
# Out:
# 'CHIRAG'

# %%
sentence="   hii my name is chirag"

# %%
sentence.strip()
# Out:
# 'hii my name is chirag'

# %%
sentence.replace('chirag','tanishq')
# Out:
# 'hii my name is tanishq'

# %%
print(sentence)
# Out:
# hii my name is chirag

# %%
sentence.split()
# Out:
# ['hii', 'my', 'name', 'is', 'chirag']

# %%
print("-".join(sentence))
# Out:
# h-i-i- -m-y- -n-a-m-e- -i-s- -c-h-i-r-a-g
