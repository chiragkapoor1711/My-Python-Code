# %% [markdown]
# **OOPS**

# %% [markdown]
# oops is way to writing a code in class and objects , class is a collection of objects, and object is a instance of a class

# %% [markdown]
# **4 - pillars of oops**
# 1. encapsulation
# 2. inheritance
# 3. polymorphism
# 4. abstarction

# %% [markdown]
# #oops

# %%
class sum:
    x = 44
ob1 = sum()
print(ob1.x)
# Out:
# 44

# %%
type(ob1)
# Out:
# __main__.sum

# %%
class calc:
    def add(self,a,b):
        print(a+b)
    def sub(self,a,b):
        print(a-b)
obj1 = calc()
obj1.add(4,5)
obj1.sub(4,2)
# Out:
# 9
# 2

# %%
class king:
    def __init__(self,name):
        self.name=name
        print("this code is on name of",self.name)
    def add(self,a,b):
        print(a+b)
    def info(self):
        print("this belong to :",self.name)

# %%
obj1 = king('chirag')
obj1.info()
# Out:
# this code is on name of chirag
# this belong to : chirag

# %%
class parent:
    def par(self):
        print("parent class")
class parent2:
    def par2(self):
        print("parent 2")
class child(parent,parent2):
    pass
obj1 = child()
obj1.par2()
# Out:
# parent 2

# %%
class a:
    def a(self):
        print("a")
class b(a):
    def b(self):
        print("b")
class c(b):
    def c(self):
        print("c")
class aa:
    def aa(self):
        print("aa")
class bb(aa):
    def bb(self):
        print("bb")
class cc(bb):
    def cc(self):
        print("cc")
class  
    pass
obj = abc()
obj.a()
obj.b()
obj.c()
obj.aa()
obj.bb()
obj.cc()
# Out:
# a
# b
# c
# aa
# bb
# cc

# %%
class calc:
    def add(self,a,b):
        print(a+b)
    def add(self,a,b,c):
        print(a+b+c)
check = calc()
check.add(2,3,4)
# Out:
# 9

# %%
class calc2:
    sum=0
    def add(self, *args):
        for i in args:
            self.sum = self.sum +  i
        print(self.sum)
obj = calc2()
obj.add(1,6,3,4)
# Out:
# 14

# %%
class bankaccount:
    def __init__(self,name,balance=0):
        self.name=name
        self.balance=balance
        self.transactions = []
        self.transactions.append(f"name:-{name}")
        self.transactions.append(f"opening balance = { balance }")
        username= input("enter username")
        password =input("enter password")
        if username == "chirag" and password =="123":
            print("welcome to our bank")
        else:
            print("username and password is wrong")
        
    def deposit(self,amount):
        if amount > 0:
            self.balance += amount
            self.transactions.append(f"deposit amount is { amount } and balance is {self.balance}")
        else:
            print('amount must be in postive')
    def viewbalance(self):
        print(f"{self.name},{self.balance}")
    def transaction(self):
        for i in self.transactions:
            print(i)
obj = bankaccount("chirag",200)
# Out:
# enter username chirag
# enter password 123
# welcome to our bank

# %%
obj.deposit(100)

# %%
obj.viewbalance()
# Out:
# chirag,300

# %%
obj.transaction()
# Out:
# name:-chirag
# opening balance = 200
# deposit amount is 100 and balance is 300

# %%
import re
class bankaccount:
    def __init__(self):
        self.name=input('enter name for customer')
        self.balance=int(input('enter opening balance for account'))
        self.username=input('enter username')
        while True:
            self.password = input('Enter password: ')
            pattern = r'^(?=.*[A-Z])(?=.*[a-z])(?=.*\d)(?=.*[@$!%*?&])[A-Za-z\d@$!%*?&]{8,}$'
            if re.match(pattern, self.password):
                print("Strong password accepted")
                break
            else:
                print("Weak password!")
                print("Password must contain:")
                print("- Minimum 8 characters")
                print("- 1 uppercase letter")
                print("- 1 lowercase letter")
                print("- 1 digit")
                print("- 1 special character (@$!%*?&)")
        self.transactions=[]
        self.transactions.append(f"Name:- {self.name}")
        self.transactions.append(f"opening balance= {self.balance}")
        print('welcome to our bank')
    def deposit(self):
        self.user=input('enter username')
        self.passw=input('enter password')
        if self.user==self.username and self.passw==self.password:
            self.amount=int(input('enter amount to deposit'))
            if self.amount >0:
                self.balance+=self.amount
                self.transactions.append(f"deposit amount is {self.amount} and balance is {self.balance}")
            else:
                print('amount must be in positive')
        else:
            print('wrong username')
    def withdrawl(self, amount):
        self.user=input('enter username')
        self.passw=input('enter password')
        if self.user==self.username and self.passw==self.password:
            if amount<self.balance:
                self.balance-=amount
            else:
                print('insufficient balance')
            self.transactions.append(f"withdraw amount:- {amount} balance= {self.balance}")
        else:
            print('authentication failed')
    def viewbalance(self):
        print(f"{self.name}, {self.balance}")
    def transaction(self):
        for i in self.transactions:
            print(i)
obj = bankaccount()
# Out:
# enter name for customer chirag
# enter opening balance for account 200
# enter username chirag
# Enter password:  chirag@123
# Weak password!
# Password must contain:
# - Minimum 8 characters
# - 1 uppercase letter
# - 1 lowercase letter
# - 1 digit
# - 1 special character (@$!%*?&)
# Enter password:  chirag@123$
# Weak password!
# Password must contain:
# - Minimum 8 characters
# - 1 uppercase letter
# - 1 lowercase letter
# - 1 digit
# - 1 special character (@$!%*?&)
# Enter password:  Chirag@123&
# Strong password accepted
# welcome to our bank

# %%
obj.deposit()
# Out:
# enter username chirag
# enter password Chirag@123&
# enter amount to deposit 200
